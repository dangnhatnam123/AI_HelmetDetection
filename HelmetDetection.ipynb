# %% [markdown]
# <a href="https://colab.research.google.com/github/dangnhatnam123/AI_HelmetDetection/blob/main/HelmetDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive/
# Out:
# HelmetDetection.ipynb  helmet_project

# %%
# !mkdir -p /content/drive/MyDrive/helmet_project

# %%
# %cd /content/drive/MyDrive/helmet_project
# Out:
# /content/drive/MyDrive/helmet_project

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 38.4 MB/s eta 0:00:00
# ...

# %%
import ultralytics
from ultralytics import YOLO
import torch
import os
ultralytics.checks()
# Out:
# Ultralytics 8.4.23 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.5/112.6 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="4GRRYVji3sL0Pb1nsrtV")
project = rf.workspace("haidanguit").project("cs114_helmet_detection_final")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to CS114_helmet_detection_Final-3 in yolov8:: 100%|██████████| 4132/4132 [00:44<00:00, 92.55it/s]

# %%
from ultralytics import YOLO
import os
model = YOLO('yolov8n.pt')
data_path = os.path.join(dataset.location, "data.yaml")
results = model.train(
    data=data_path,
    epochs=50,
    imgsz=640,
    device=0,
    name='helmet_detection_v1'
)
# Out:
# ...
# Ultralytics 8.4.23 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
